# %% [markdown]
# <a href="https://colab.research.google.com/github/noshi258/Assignment_04/blob/main/02_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("01_add_many_number")

def add_numbers(numbers)-> int:
    num: int = 0
    for n in numbers:
        num += n

    return num

def main():
    numbers: list[int] = [1, 2, 3, 4, 5, 6]
    sum: int = add_numbers(numbers)
    print(sum)


if __name__ == '__main__':
    main()
# Out:
# 01_add_many_number
# 21

# %%
print("02_double_list")

def main():
    numbers: list[int] = [1, 2, 3, 4, 5]

    for i in range(len(numbers)):
        index = numbers[i]
        numbers[i] = index * 2

    print(numbers)

if __name__ == '__main__':
    main()
# Out:
# 02_double_list
# [2, 4, 6, 8, 10]

# %%
print("04_flowing_with_data_structures")

def add_copies(my_list, data):
    for i in range(3):
        my_list.append(data)

def main():
    message = input("Enter a message to copy: ")
    my_list = []
    print("List before:", my_list)
    add_copies(my_list, message)
    print("List after:", my_list)

if __name__ == "__main__":
    main()
# Out:
# 04_flowing_with_data_structures
# Enter a message to copy: Hello World
# List before: []
# List after: ['Hello World', 'Hello World', 'Hello World']

# %%
print("05_get_first_element")


def get_first_element(lst):

    print(lst[0])

def get_lst():
    lst = []
    element: str = input("Please enter an element to add to the list.")
    while element != "":
        lst.append(element)
        return lst

def main():
    lst = get_lst()
    get_first_element(lst)


if __name__ == '__main__':
    main()
# Out:
# 05_get_first_element
# Please enter an element to add to the list.36
# 36

# %%
print("06_get_last_element")

def get_first_element(lst):

    print(lst[-1])

def main():
  lst = [1, 2, 3, 4, 5]
  get_first_element(lst)

if __name__ == '__main__':
    main()
# Out:
# 06_get_last_element
# 5

# %%
print("07_get_list")

def main():
    lst = []
    val = input("Enter a value: ")
    while val:
        lst.append(val)
        val = input("Enter a value: ")

    print("Here's the list:", lst)

if __name__ == '__main__':
    main()
# Out:
# 07_get_list
# Enter a value: 1
# Enter a value: 2
# Enter a value: 3
# Enter a value: 4
# Enter a value: 5
# Enter a value:
# Here's the list: ['1', '2', '3', '4', '5']

# %%
print("08_shorten")

MAX_LENGTH : int = 3

def shorten(lst):
    while len(lst) > MAX_LENGTH:
        last_elem = lst.pop()
        print(last_elem)

def get_lst():

    lst = []
    element = input("Please enter an element of the list. ")
    while element != "":
        lst.append(element)
        element = input("Please enter an element of the list. ")
    return lst

def main():
    lst = get_lst()
    shorten(lst)


if __name__ == '__main__':
    main()
# Out:
# 08_shorten
# Please enter an element of the list. Nosheen
# Please enter an element of the list. Ashfaq
# Please enter an element of the list.
